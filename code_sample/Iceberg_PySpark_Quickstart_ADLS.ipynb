# %% [markdown]
# # Using Apache Iceberg with Spark 3 in CML

# %% [markdown]
# The official documentation for Apache Iceberg with Spark is located at [this link](https://iceberg.apache.org/#getting-started/#using-iceberg-in-spark-3)

# %% [markdown]
# For a full list of Apache Iceberg terms, please visit [this link](https://iceberg.apache.org/#terms/)

# %%
spark.sql("DROP TABLE IF EXISTS spark_catalog.testdb.newtesttable")
spark.sql("DROP TABLE IF EXISTS spark_catalog.testdb.secondtesttable")
# Out:
# Hive Session ID = b7dbfa88-a109-42da-949b-2011342a9f60
# DataFrame[]

# %%
#spark.stop()

# %% [markdown]
# ### Start a PySpark Session as shown below. You will want to set the Spark Catalog configurations as shown

# %%
"""SimpleApp.py"""
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder\
  .appName("1.1 - Ingest") \
  .config("spark.hadoop.fs.s3a.s3guard.ddb.region", "us-east-2")\
  .config("spark.yarn.access.hadoopFileSystems", "abfs://data@go01demoazure.dfs.core.windows.net/go01-az-dl")\
  .config("spark.jars","/opt/spark/optional-lib/iceberg-spark-runtime-3.5_2.12-1.5.2.1.25.731.0-41.jar") \
  .config("spark.sql.extensions","org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
  .config("spark.sql.catalog.spark_catalog","org.apache.iceberg.spark.SparkSessionCatalog") \
  .config("spark.sql.catalog.local","org.apache.iceberg.spark.SparkCatalog") \
  .config("spark.sql.catalog.local.type","hadoop") \
  .config("spark.sql.catalog.spark_catalog.type","hive") \
  .getOrCreate()
# Out:
# Setting spark.hadoop.yarn.resourcemanager.principal to vishrajagopalan

# %% [markdown]
# ### Iceberg comes with catalogs that enable SQL commands to manage tables and load them by name.
# ### Catalogs are configured using properties under spark.sql.catalog.(catalog_name).

# %%
  # Using a local Spark Catalog

#spark.sql("CREATE DATABASE IF NOT EXISTS spark_catalog.newjar")
spark.sql("USE spark_catalog.testdb")
spark.sql("SHOW CURRENT NAMESPACE").show()
#spark.sql("DROP TABLE testtable")
# Out:
# Hive Session ID = ba0f122b-c48e-43a9-bcca-0e9c9927f8bf
# +-------------+---------+
# |      catalog|namespace|
# +-------------+---------+
# |spark_catalog|   testdb|
# +-------------+---------+

# %% [markdown]
# ### You can use simple Spark SQL commands to create Spark tables as you always have. Just make sure to specify the USING iceberg clause.

# %%
spark.sql("CREATE TABLE IF NOT EXISTS newtesttable (id bigint, data string) USING iceberg")
# Out:
# DataFrame[]

# %% [markdown]
# ### To select a specific table snapshot or the snapshot at some time, Iceberg supports two Spark read options:
#
# * snapshot-id selects a specific table snapshot
# * as-of-timestamp selects the current snapshot at a timestamp, in milliseconds

# %% [markdown]
# #### You can view all snapshots associated with the table

# %%
spark.sql("SELECT * FROM spark_catalog.testdb.newtesttable")
# Out:
# DataFrame[id: bigint, data: string]

# %%
spark.read.format("iceberg").table("spark_catalog.testdb.newtesttable.snapshots").show(20, False)
# Out:
# +-----------------------+-------------------+-------------------+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |committed_at           |snapshot_id        |parent_id          |operation|manifest_list                                                                                                                                                                         |summary                                                                                                                                                                                                                                                                                                              |
# +-----------------------+-------------------+-------------------+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2026-08-17 06:31:26.128|5931245036883003375|NULL               |append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-5931245036883003375-1-ddb5a66e-f79e-49e7-8d3a-6a42d4c54a70.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 2, added-records -> 3, added-files-size -> 1259, changed-partition-count -> 1, total-records -> 3, total-files-size -> 1259, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}  |
# |2026-08-17 06:35:48.786|7393716735549598733|5931245036883003375|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-7393716735549598733-1-50c74124-6dc6-4315-9c96-efe35a9a8851.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 2, added-records -> 3, added-files-size -> 1259, changed-partition-count -> 1, total-records -> 6, total-files-size -> 2518, total-data-files -> 4, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}  |
# |2026-08-17 06:35:55.369|7873606017154260794|7393716735549598733|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-7873606017154260794-1-1a037ef5-7252-40fd-9b8e-eecd5a432265.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 2, added-records -> 3, added-files-size -> 1259, changed-partition-count -> 1, total-records -> 9, total-files-size -> 3777, total-data-files -> 6, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}  |
# |2026-08-17 06:36:00.302|2172668620878660715|7873606017154260794|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-2172668620878660715-1-51797395-e23c-4fb7-b094-c24b46894022.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 10, total-files-size -> 4402, total-data-files -> 7, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}  |
# |2026-08-17 06:36:01.033|3646232688089283802|2172668620878660715|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-3646232688089283802-1-23b14665-5382-49ba-943b-730502f6f77b.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 11, total-files-size -> 5027, total-data-files -> 8, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}  |
# |2026-08-17 06:36:01.783|8637290749067041674|3646232688089283802|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-8637290749067041674-1-f505e8ac-f336-4c01-af07-4a777902f230.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 12, total-files-size -> 5652, total-data-files -> 9, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}  |
# |2026-08-17 06:36:02.499|715653241292011823 |8637290749067041674|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-715653241292011823-1-7529e11c-253d-4744-9d50-1c6dc46073f0.avro |{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 13, total-files-size -> 6277, total-data-files -> 10, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0} |
# |2026-08-17 06:36:03.242|7790846203986143000|715653241292011823 |append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-7790846203986143000-1-b53c0577-b32b-4f58-82cf-7ef51ce9b98c.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 14, total-files-size -> 6902, total-data-files -> 11, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0} |
# |2026-08-17 06:36:04.014|2659862849294321716|7790846203986143000|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-2659862849294321716-1-86f14e49-e31a-4a68-98b4-40bbb52ead8a.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 15, total-files-size -> 7527, total-data-files -> 12, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0} |
# |2026-08-17 06:36:04.744|4383726862271827238|2659862849294321716|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-4383726862271827238-1-e6c507c6-47c4-44b3-b151-6ed420e9b909.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 624, changed-partition-count -> 1, total-records -> 16, total-files-size -> 8151, total-data-files -> 13, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0} |
# |2026-08-17 06:36:05.475|5478247642825826716|4383726862271827238|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-5478247642825826716-1-89513812-7aab-4610-bcc0-ed832b817de1.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 624, changed-partition-count -> 1, total-records -> 17, total-files-size -> 8775, total-data-files -> 14, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0} |
# |2026-08-17 06:36:06.196|5191293387943559585|5478247642825826716|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-5191293387943559585-1-51a70762-da51-404a-9ede-aa952fd26d2f.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 18, total-files-size -> 9400, total-data-files -> 15, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0} |
# |2026-08-17 06:36:06.885|4595144081537741756|5191293387943559585|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-4595144081537741756-1-642f84bc-b98f-44ba-907f-c4e85062bc68.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 624, changed-partition-count -> 1, total-records -> 19, total-files-size -> 10024, total-data-files -> 16, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-08-17 06:36:07.646|6440597874519409227|4595144081537741756|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-6440597874519409227-1-dfe0d4e1-cc37-41d4-ab91-1a850f9af0ef.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 20, total-files-size -> 10649, total-data-files -> 17, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-08-17 06:36:08.347|5550835341462924902|6440597874519409227|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-5550835341462924902-1-ebc13fcf-6d72-4f3a-97a9-3554ce0bf255.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 21, total-files-size -> 11274, total-data-files -> 18, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-08-17 06:36:09.075|2110055541917923611|5550835341462924902|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-2110055541917923611-1-a315a24d-8292-45cb-b74f-fc8315480729.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 22, total-files-size -> 11899, total-data-files -> 19, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-08-17 06:36:09.798|3320323547398232631|2110055541917923611|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-3320323547398232631-1-679f65c1-9e6d-4750-94b6-9212ccbf5cb8.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 23, total-files-size -> 12524, total-data-files -> 20, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-08-17 06:36:10.533|5578114220418141524|3320323547398232631|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-5578114220418141524-1-c77416b5-00cf-4b06-8c7f-a24319568b25.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 24, total-files-size -> 13149, total-data-files -> 21, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-08-17 06:36:11.249|5157313015173135612|5578114220418141524|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-5157313015173135612-1-622f30b1-52ba-405c-8ac9-e0db5f658af3.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 25, total-files-size -> 13774, total-data-files -> 22, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-08-17 06:36:11.96 |4342518085953304355|5157313015173135612|append   |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/snap-4342518085953304355-1-4629bdb2-bd0a-4c0b-8dc3-600c4585e9e0.avro|{spark.app.id -> spark-d9f9c18776d34f2da76f60b6e25a0e18, added-data-files -> 1, added-records -> 1, added-files-size -> 625, changed-partition-count -> 1, total-records -> 26, total-files-size -> 14399, total-data-files -> 23, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# +-----------------------+-------------------+-------------------+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# #### Or a full table version history

# %%
spark.read.format("iceberg").table("spark_catalog.testdb.newtesttable.history").show(20, False)
# Out:
# +-----------------------+-------------------+-------------------+-------------------+
# |made_current_at        |snapshot_id        |parent_id          |is_current_ancestor|
# +-----------------------+-------------------+-------------------+-------------------+
# |2026-08-17 06:31:26.128|5931245036883003375|NULL               |true               |
# |2026-08-17 06:35:48.786|7393716735549598733|5931245036883003375|true               |
# |2026-08-17 06:35:55.369|7873606017154260794|7393716735549598733|true               |
# |2026-08-17 06:36:00.302|2172668620878660715|7873606017154260794|true               |
# |2026-08-17 06:36:01.033|3646232688089283802|2172668620878660715|true               |
# |2026-08-17 06:36:01.783|8637290749067041674|3646232688089283802|true               |
# |2026-08-17 06:36:02.499|715653241292011823 |8637290749067041674|true               |
# |2026-08-17 06:36:03.242|7790846203986143000|715653241292011823 |true               |
# |2026-08-17 06:36:04.014|2659862849294321716|7790846203986143000|true               |
# |2026-08-17 06:36:04.744|4383726862271827238|2659862849294321716|true               |
# |2026-08-17 06:36:05.475|5478247642825826716|4383726862271827238|true               |
# |2026-08-17 06:36:06.196|5191293387943559585|5478247642825826716|true               |
# |2026-08-17 06:36:06.885|4595144081537741756|5191293387943559585|true               |
# |2026-08-17 06:36:07.646|6440597874519409227|4595144081537741756|true               |
# |2026-08-17 06:36:08.347|5550835341462924902|6440597874519409227|true               |
# |2026-08-17 06:36:09.075|2110055541917923611|5550835341462924902|true               |
# |2026-08-17 06:36:09.798|3320323547398232631|2110055541917923611|true               |
# |2026-08-17 06:36:10.533|5578114220418141524|3320323547398232631|true               |
# |2026-08-17 06:36:11.249|5157313015173135612|5578114220418141524|true               |
# |2026-08-17 06:36:11.96 |4342518085953304355|5157313015173135612|true               |
# +-----------------------+-------------------+-------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# #### To show a table’s data files and each file’s metadata, run:

# %%
spark.read.format("iceberg").table("spark_catalog.testdb.newtesttable.files").show(20, False)
# Out:
# [Stage 4:>                                                          (0 + 1) / 1]
# +-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-------+------------+------------------+------------------+----------------+-----------------+----------------+-------------------------------------------+-------------------------------------------+------------+-------------+------------+-------------+------------------------------------------------+
# |content|file_path                                                                                                                                                                 |file_format|spec_id|record_count|file_size_in_bytes|column_sizes      |value_counts    |null_value_counts|nan_value_counts|lower_bounds                               |upper_bounds                               |key_metadata|split_offsets|equality_ids|sort_order_id|readable_metrics                                |
# +-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-------+------------+------------------+------------------+----------------+-----------------+----------------+-------------------------------------------+-------------------------------------------+------------+-------------+------------+-------------+------------------------------------------------+
# |0      |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/data/00000-1-ea23b4eb-7f0d-42f9-b131-6ec9d458a601-0-00001.parquet|PARQUET    |0      |1           |625               |{1 -> 33, 2 -> 30}|{1 -> 1, 2 -> 1}|{1 -> 0, 2 -> 0} |{}              |{1 -> [01 00 00 00 00 00 00 00], 2 -> [78]}|{1 -> [01 00 00 00 00 00 00 00], 2 -> [78]}|NULL        |[4]          |NULL        |0            |{{30, 1, 0, NULL, x, x}, {33, 1, 0, NULL, 1, 1}}|
# |0      |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/data/00001-2-ea23b4eb-7f0d-42f9-b131-6ec9d458a601-0-00001.parquet|PARQUET    |0      |2           |634               |{1 -> 41, 2 -> 35}|{1 -> 2, 2 -> 2}|{1 -> 0, 2 -> 0} |{}              |{1 -> [02 00 00 00 00 00 00 00], 2 -> [79]}|{1 -> [03 00 00 00 00 00 00 00], 2 -> [7A]}|NULL        |[4]          |NULL        |0            |{{35, 2, 0, NULL, y, z}, {41, 2, 0, NULL, 2, 3}}|
# +-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-------+------------+------------------+------------------+----------------+-----------------+----------------+-------------------------------------------+-------------------------------------------+------------+-------------+------------+-------------+------------------------------------------------+

# %% [markdown]
# ### A manifest file is a metadata file that lists a subset of data files that make up a snapshot.
#
# ### Each data file in a manifest is stored with a partition tuple, column-level stats, and summary information used to prune splits during scan planning.

# %% [markdown]
# #### To show a table’s file manifests and each file’s metadata, run:

# %%
spark.read.format("iceberg").table("spark_catalog.testdb.newtesttable.manifests").show(20, False)
# Out:
# +-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+------+-----------------+-------------------+----------------------+-------------------------+------------------------+------------------------+---------------------------+--------------------------+-------------------+
# |content|path                                                                                                                                                          |length|partition_spec_id|added_snapshot_id  |added_data_files_count|existing_data_files_count|deleted_data_files_count|added_delete_files_count|existing_delete_files_count|deleted_delete_files_count|partition_summaries|
# +-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+------+-----------------+-------------------+----------------------+-------------------------+------------------------+------------------------+---------------------------+--------------------------+-------------------+
# |0      |abfs://data@go01demoazure.dfs.core.windows.net/warehouse/tablespace/external/hive/testdb.db/newtesttable/metadata/ddb5a66e-f79e-49e7-8d3a-6a42d4c54a70-m0.avro|6759  |0                |5931245036883003375|2                     |0                        |0                       |0                       |0                          |0                         |[]                 |
# +-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+------+-----------------+-------------------+----------------------+-------------------------+------------------------+------------------------+---------------------------+--------------------------+-------------------+

# %% [markdown]
# ## Time Travel

# %% [markdown]
# ### Using snapshots as shown above, we can insert some data into the table and roll back to its original state

# %%
# Insert using Iceberg format
spark.sql("INSERT INTO spark_catalog.testdb.newtesttable VALUES (1, 'x'), (2, 'y'), (3, 'z')")
# Out:
# DataFrame[]

# %%
# Query using select
spark.sql("SELECT * FROM spark_catalog.testdb.newtesttable").show()
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# +---+----+
# | id|data|
# +---+----+
# |  1|   x|
# |  2|   y|
# |  3|   z|
# +---+----+

# %%
# Query using DF - All Data
df = spark.table("spark_catalog.testdb.newtesttable")
df.show(100)
# Out:
# +---+----+
# | id|data|
# +---+----+
# |  1|   x|
# |  2|   y|
# |  3|   z|
# +---+----+

# %%
from datetime import datetime

# current date and time
now = datetime.now()

timestamp = datetime.timestamp(now)
print("timestamp =", timestamp)
# Out:
# timestamp = 1786948463.806746

# %%
# View commit history with timestamps
spark.sql("SELECT made_current_at, snapshot_id FROM spark_catalog.testdb.newtesttable.history").show(truncate=False)

# View detailed snapshot metadata
spark.sql("SELECT committed_at, snapshot_id, operation FROM spark_catalog.testdb.newtesttable.snapshots").show(truncate=False)
# Out:
# +-----------------------+-------------------+
# |made_current_at        |snapshot_id        |
# +-----------------------+-------------------+
# |2026-08-17 06:31:26.128|5931245036883003375|
# +-----------------------+-------------------+
#
# +-----------------------+-------------------+---------+
# |committed_at           |snapshot_id        |operation|
# +-----------------------+-------------------+---------+
# |2026-08-17 06:31:26.128|5931245036883003375|append   |
# +-----------------------+-------------------+---------+

# %% [markdown]
# #### Timestamps can be tricky. Please make sure to round your timestamp as shown below.

# %%
# Query using a point in time
df = spark.read.option("as-of-timestamp", int(timestamp*1000)).format("iceberg").table("spark_catalog.testdb.newtesttable")
df.show(100)
# Out:
# [Stage 8:>                                                          (0 + 1) / 1]
# +---+----+
# | id|data|
# +---+----+
# |  1|   x|
# |  2|   y|
# |  3|   z|
# +---+----+

# %%
# Insert using Iceberg format
spark.sql("INSERT INTO spark_catalog.testdb.newtesttable VALUES (1, 'd'), (2, 'e'), (3, 'f')")
# Out:
# DataFrame[]

# %% [markdown]
# ### Let's insert more data into the table

# %%
# Insert using Iceberg format
import string
import random

for i in range(25):
    number = random.randint(0, 10)
    letter = random.choice(string.ascii_letters)
    spark.sql("INSERT INTO spark_catalog.testdb.newtesttable VALUES ({}, '{}')".format(number, letter))

# %% [markdown]
# ### Now let's access the data again. Let's access it with the same timestemp as before. Notice we have a smaller number of rows than we just inserted.

# %%
# Query using a point in time
df = spark.read.option("as-of-timestamp", int(timestamp*1000)).format("iceberg").table("spark_catalog.testdb.newtesttable")
df.show(100)
# Out:
# +---+----+
# | id|data|
# +---+----+
# |  1|   x|
# |  2|   y|
# |  3|   z|
# +---+----+

# %% [markdown]
# ### Observe that many new Snapshots have been created

# %%
spark.read.format("iceberg").table("spark_catalog.testdb.newtesttable.history").show(10, False)
# Out:
# +-----------------------+-------------------+-------------------+-------------------+
# |made_current_at        |snapshot_id        |parent_id          |is_current_ancestor|
# +-----------------------+-------------------+-------------------+-------------------+
# |2026-08-17 06:31:26.128|5931245036883003375|NULL               |true               |
# |2026-08-17 06:35:48.786|7393716735549598733|5931245036883003375|true               |
# |2026-08-17 06:35:55.369|7873606017154260794|7393716735549598733|true               |
# |2026-08-17 06:36:00.302|2172668620878660715|7873606017154260794|true               |
# |2026-08-17 06:36:01.033|3646232688089283802|2172668620878660715|true               |
# |2026-08-17 06:36:01.783|8637290749067041674|3646232688089283802|true               |
# |2026-08-17 06:36:02.499|715653241292011823 |8637290749067041674|true               |
# |2026-08-17 06:36:03.242|7790846203986143000|715653241292011823 |true               |
# |2026-08-17 06:36:04.014|2659862849294321716|7790846203986143000|true               |
# |2026-08-17 06:36:04.744|4383726862271827238|2659862849294321716|true               |
# +-----------------------+-------------------+-------------------+-------------------+
# only showing top 10 rows

# %% [markdown]
# ### You can also query the table in its previous state as of a specific partition.

# %% [markdown]
# #### Copy paste a partition_id from above and paste it in the next Spark command

# %%
spark.read\
    .option("snapshot-id", 3646232688089283802)\
    .table("spark_catalog.testdb.newtesttable").show()
# Out:
# +---+----+
# | id|data|
# +---+----+
# |  3|   i|
# |  1|   d|
# |  2|   e|
# |  3|   f|
# |  1|   x|
# |  2|   y|
# |  3|   z|
# | 10|   g|
# |  1|   d|
# |  2|   e|
# |  3|   f|
# +---+----+

# %% [markdown]
# ### The Iceberg API allows you to create tables from Spark Dataframes, and more

# %%
new_df = spark.sql("SELECT * FROM spark_catalog.testdb.newtesttable").sample(fraction=0.5, seed=3)

# %%
new_df.dtypes
# Out:
# [('id', 'bigint'), ('data', 'string')]

# %%
new_df.show(10)
# Out:
# +---+----+
# | id|data|
# +---+----+
# |  9|   i|
# |  2|   e|
# |  3|   f|
# |  3|   m|
# | 10|   l|
# |  1|   d|
# |  2|   e|
# |  7|   P|
# |  1|   Z|
# |  2|   y|
# +---+----+
# only showing top 10 rows

# %% [markdown]
# #### Creating a new Spark Table with the API and Loading It

# %%
spark.sql("DROP TABLE IF EXISTS spark_catalog.testdb.secondtesttable")
# Out:
# DataFrame[]

# %%
new_df.writeTo("spark_catalog.testdb.secondtesttable").create()

# %%
new_df_nodups = new_df.dropDuplicates(["id"])

# %%
new_df_nodups.show()
# Out:
# [Stage 43:==================================================>       (7 + 1) / 8]
# +---+----+
# | id|data|
# +---+----+
# |  0|   I|
# |  1|   x|
# |  2|   e|
# |  3|   f|
# |  4|   N|
# |  5|   L|
# |  6|   N|
# |  7|   P|
# |  9|   J|
# | 10|   l|
# +---+----+

# %% [markdown]
# #### More ETL SQL Operations

# %%
spark.sql("INSERT INTO spark_catalog.testdb.secondtesttable SELECT * FROM spark_catalog.testdb.newtesttable")
# Out:
# DataFrame[]

# %%
new_df.count()
# Out:
# 19

# %%
second_df = spark.sql("SELECT * FROM spark_catalog.testdb.secondtesttable")

# %%
second_df.count()
# Out:
# 53

# %%
second_df=second_df.withColumn("id", second_df.id*3)

# %%
sec_df_nodups = second_df.dropDuplicates(["id"])

# %%
sec_df_nodups.show()
# Out:
# +---+----+
# | id|data|
# +---+----+
# |  0|   J|
# |  6|   e|
# |  9|   E|
# | 27|   K|
# |  3|   d|
# | 12|   K|
# | 18|   K|
# | 21|   t|
# | 15|   v|
# | 30|   B|
# | 24|   p|
# +---+----+

# %%
#new_df_nodups.writeTo("spark_catalog.testdb.new_df_nodups").create()

# %%
#sec_df_nodups.writeTo("spark_catalog.testdb.sec_df_nodups").create()

# %% [markdown]
# #### Update and Merge Into SQL Operations

# %%
#spark.sql("UPDATE spark_catalog.testdb.new_df_nodups SET data = '?' WHERE id = (SELECT id FROM spark_catalog.testdb.sec_df_nodups)")

# %%
#spark.sql(
#"MERGE INTO spark_catalog.testdb.new_df_nodups t USING (SELECT * FROM spark_catalog.testdb.sec_df_nodups) u ON t.id = u.id \
#WHEN MATCHED THEN UPDATE SET t.data = u.data + t.data \
#WHEN NOT MATCHED THEN INSERT *")

# %%
#spark.sql("SELECT count(*) FROM spark_catalog.testdb.new_df_nodups").show()

# %%
#spark.sql("SELECT * FROM spark_catalog.testdb.new_df_nodups").show()
